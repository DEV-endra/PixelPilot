# %%
# !pip install mss pydirectinput pytesseract
# !pip install stable-baselines3[extra]
# Out:
# Requirement already satisfied: mss in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (10.0.0)
# Requirement already satisfied: pydirectinput in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (1.0.4)
# Requirement already satisfied: pytesseract in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (0.3.13)
# Requirement already satisfied: packaging>=21.3 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from pytesseract) (24.2)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from pytesseract) (11.1.0)
# Requirement already satisfied: stable-baselines3[extra] in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (2.5.0)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: numpy<3.0,>=1.20 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from stable-baselines3[extra]) (2.2.2)
# Requirement already satisfied: torch<3.0,>=2.3 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from stable-baselines3[extra]) (2.6.0)
# Requirement already satisfied: cloudpickle in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from stable-baselines3[extra]) (3.1.1)
# Requirement already satisfied: pandas in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from stable-baselines3[extra]) (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from stable-baselines3[extra]) (3.10.0)
# Requirement already satisfied: opencv-python in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from stable-baselines3[extra]) (4.11.0.86)
# Requirement already satisfied: pygame in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from stable-baselines3[extra]) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from stable-baselines3[extra]) (2.18.0)
# Requirement already satisfied: psutil in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from stable-baselines3[extra]) (5.9.0)
# Requirement already satisfied: tqdm in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from stable-baselines3[extra]) (4.67.1)
# Requirement already satisfied: rich in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from stable-baselines3[extra]) (13.9.4)
# Requirement already satisfied: ale-py>=0.9.0 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from stable-baselines3[extra]) (0.10.1)
# Requirement already satisfied: pillow in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from stable-baselines3[extra]) (11.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3[extra]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: absl-py>=0.4 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.70.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.7)
# Requirement already satisfied: packaging in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (24.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (75.8.0)
# Requirement already satisfied: six>1.9 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.1.3)
# Requirement already satisfied: filelock in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.17.0)
# Requirement already satisfied: networkx in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.1.5)
# Requirement already satisfied: fsspec in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (2025.2.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from pandas->stable-baselines3[extra]) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from pandas->stable-baselines3[extra]) (2025.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from rich->stable-baselines3[extra]) (2.15.1)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from tqdm->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.2)

# %%
# !pip install gym
from mss import mss    # mss used for screen capture
import pydirectinput   # sending commands
import cv2             # open cv for frame processing
import numpy as np 
import pytesseract     # FOR OPTICAL CHARACTER RECOGNITION
from matplotlib import pyplot as plt
import time 
from gymnasium import spaces
from gymnasium import Env
from PIL import Image
from gym.spaces import Box, Discrete
import cv2
import numpy as np
import gym
# Out:
# Requirement already satisfied: gym in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (0.26.2)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from gym) (2.2.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from gym) (3.1.1)
# Requirement already satisfied: gym_notices>=0.0.4 in c:\users\hp\anaconda3\envs\gymenv\lib\site-packages (from gym) (0.0.8)

# %%
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
def preprocessing(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Increase contrast and sharpness
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)
    sharpened = cv2.addWeighted(gray, 1.5, blurred, -0.5, 0)

    # Apply adaptive thresholding
    thresh = cv2.adaptiveThreshold(
            sharpened, 255, 
            cv2.ADAPTIVE_THRESH_MEAN_C, 
            cv2.THRESH_BINARY_INV, 
            15, 8
        )

    # Morphological operations
    kernel = np.ones((3,3), np.uint8)
    dilated = cv2.dilate(thresh, kernel, iterations=2)
    eroded = cv2.erode(dilated, kernel, iterations=1)
    return eroded


def detect_objects(image):
    #print(image.shape)
    # Assuming the image shape is (height, width, 100)
    #image = image[:, :, :3]  # Take the first three channels
    # Select first three channels assuming image is in CHW format:
    image = image[:3, :, :]
    # Transpose to HWC format:
    image = np.transpose(image, (1, 2, 0))


    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    #print(hsv)
    # Define HSV color ranges for different objects
    cash_lower = np.array([50, 100, 100])    # Green (Cash)
    cash_upper = np.array([90, 255, 255]) 

    police_lower = np.array([0, 0, 0])       # Black (Police Cars)
    police_upper = np.array([180, 255, 50]) 

    player_lower = np.array([0, 150, 100])   # Red (Player Car)
    player_upper = np.array([10, 255, 255])  

    stone_lower = np.array([15, 20, 150])    # Light brown/beige
    stone_upper = np.array([35, 100, 255]) 

    # Create masks
    cash_mask = cv2.inRange(hsv, cash_lower, cash_upper)
    police_mask = cv2.inRange(hsv, police_lower, police_upper)
    player_mask = cv2.inRange(hsv, player_lower, player_upper)
    stone_mask = cv2.inRange(hsv, stone_lower, stone_upper)
    #print(police_mask)
    
    # Count pixels
    cash_pixels = np.sum(cash_mask > 0)
    police_pixels = np.sum(police_mask > 0)
    player_pixels = np.sum(player_mask > 0)
    stone_pixels = np.sum(stone_mask > 0)

    return cash_pixels, police_pixels, stone_pixels

def press(delay, key):
    pydirectinput.keyDown(key)
    time.sleep(delay)
    pydirectinput.keyUp(key)
    
class WebGame(Env):
    def __init__(self):      # Setting up the environment and observation spaces
        super().__init__()   # for using the base class of gym
        #self.observation_space = spaces.Box(low=0, high=255, shape=(1,83,100), dtype=np.uint8)
        self.observation_space = spaces.Box(low=0, high=255, shape=(3, 83, 100), dtype=np.uint8)
        self.action_space = spaces.Discrete(9)
        # Capture game frames
        self.cap = mss()
        self.game_location = {'top': 120, 'left': 610, 'width': 800, 'height':900}
        self.cash_location={'top': 330, 'left': 760, 'width': 400, 'height':410}
        self.done_location = {'top':440, 'left': 550, 'width': 380, 'height':90}

    def step(self, action):
        action_map = { 
            0:'left1',
            1: 'left2', 
            2: 'left3',
            3: 'left4',
            4: 'right1',
            5:'right2',
            6:'right3',
            7:'right4',
            8:'no_op'
        }
        if action != 8:
            if action == 0:
                press(0.1, 'left')  # left1
            elif action == 1:
                press(0.2, 'left')  # left2
            elif action == 2:
                press(0.3, 'left')  # left3
            elif action == 3:
                press(0.5, 'left')  # left4
            elif action == 4:
                press(0.1, 'right')  # right1
            elif action == 5:
                press(0.2, 'right')  # right2
            elif action == 6:
                press(0.3, 'right')  # right3
            else:
                press(0.5, 'right')  # right4

        done, done_cap = self.get_done()   
        observation = self.get_observation()

        # Detect objects
        cash_pixels2, police_pixels, stone_pixels = detect_objects(observation)
        cash_pixels, police_pixels2, stone_pixels2 = detect_objects(self.get_closer())
        # Define new reward function
        reward = 2
        # print("car pixels",police_pixels)
        if cash_pixels > 0:  # If cash is detected
            reward += 10
        if police_pixels > 20:  # If police car is detected
            reward -= 10
        if stone_pixels > 10:  # If stone is detected
            reward -= 100

        truncated = False
        info = {}
        return observation, reward, done,truncated, info
        
    def reset(self,seed=None,options=None):
        time.sleep(1)

        pydirectinput.click(x=960, y=540)
        pydirectinput.press('space')
        pydirectinput.press('space')
        return self.get_observation(),{}
        
    def render(self):
        cv2.imshow('Game', self.current_frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            self.close()
         
    def close(self): 
        cv2.destroyAllWindows()
    
    # def get_observation(self):       # processing info from the frames 
    #     raw = np.array(self.cap.grab(self.game_location))[:,:,:3].astype(np.uint8)
    #     gray = cv2.cvtColor(raw, cv2.COLOR_BGR2GRAY)
    #     resized = cv2.resize(gray, (100,83))
    #     channel = np.reshape(resized, (1,83,100))
    #     return channel
    
    def get_observation(self):       
        raw = np.array(self.cap.grab(self.game_location))  # Capture screen
        raw = cv2.cvtColor(raw, cv2.COLOR_BGRA2BGR)  # Convert from BGRA to BGR

        # Resize to (100, 83) with high-quality interpolation
        resized = cv2.resize(raw, (100, 83), interpolation=cv2.INTER_CUBIC)

        # Transpose to (Channels, Height, Width)
        return np.transpose(resized, (2, 0, 1))  # (3, 83, 100)

    def get_closer(self):     
        raw = np.array(self.cap.grab(self.cash_location))  # Capture screen
        raw = cv2.cvtColor(raw, cv2.COLOR_BGRA2BGR)  # Convert from BGRA to BGR

        # Resize to (100, 83) with high-quality interpolation
        resized = cv2.resize(raw, (100, 83), interpolation=cv2.INTER_CUBIC)

        # Transpose to (Channels, Height, Width)
        return np.transpose(resized, (2, 0, 1))  # (3, 83, 100)
    def get_reward_observation(self):       
        raw = np.array(self.cap.grab(self.game_location))  # Capture screen
        raw = cv2.cvtColor(raw, cv2.COLOR_BGRA2BGR)  # Convert from BGRA to BGR

        # Resize to (100, 83) with high-quality interpolation
        resized = cv2.resize(raw, (70, 50), interpolation=cv2.INTER_CUBIC)

        # Transpose to (Channels, Height, Width)
        return np.transpose(resized, (2, 0, 1))  # (3, 83, 100)
    
    def get_done(self):
        done_cap = np.array(self.cap.grab(self.done_location)).astype(np.uint8)
        plt.imshow(self.cap.grab(self.done_location))

        done_cap=preprocessing(done_cap)

        done_strings = ['HIGH']
        done=False
        # if np.sum(done_cap) < 44300000:
        #     done = True
        done = False
        custom_config = r'--oem 3 --psm 6'
        res = pytesseract.image_to_string(done_cap, config=custom_config)[:4]
        
        # print(res)
        if res in done_strings:
            done = True
        return done, done_cap

# %%
env = WebGame()

# %%
obs=env.get_closer ()

# %%
# plt.imshow(cv2.cvtColor(obs[0], cv2.COLOR_GRAY2BGR))
plt.imshow(cv2.cvtColor(obs.transpose(1, 2, 0), cv2.COLOR_BGR2RGB))

# %%
# done, done_cap = env.get_done()
# done

# %%
# pytesseract.image_to_string(done_cap)

# %%
# env.action_space.sample()

# %%
for episode in range(1): 
    obs = env.reset()
    done = False  
    total_reward = 0  
    while not done: 
        # a=env.action_space.sample()
        #print(a)
        obs, reward, done,_,info =  env.step(8)
        total_reward  += reward  
    print('Total Reward for episode {} is {}'.format(episode, total_reward))
# Out:
# car pixels 0
# car pixels 0
# car pixels 0
# car pixels 0
# car pixels 0
# car pixels 3
# car pixels 11
# car pixels 1
# car pixels 0
# car pixels 0
# car pixels 0
# car pixels 0
# car pixels 0
# car pixels 0
# car pixels 0
# car pixels 0
# car pixels 0
# car pixels 2
# car pixels 3
# car pixels 8
# car pixels 6
# car pixels 10
# car pixels 12
# car pixels 16
# car pixels 23
# car pixels 9
# car pixels 11
# car pixels 9
# car pixels 12
# car pixels 23
# car pixels 12
# car pixels 5
# car pixels 9
# car pixels 11
# car pixels 7
# car pixels 4
# car pixels 2
# car pixels 2
# car pixels 10
# car pixels 12
# car pixels 14
# car pixels 26
# car pixels 19
# car pixels 19
# car pixels 19
# car pixels 29
# car pixels 30
# car pixels 35
# car pixels 33
# car pixels 34
# car pixels 41
# car pixels 33
# car pixels 22
# car pixels 23
# car pixels 11
# car pixels 12
# car pixels 17
# car pixels 13
# car pixels 17
# car pixels 17
# car pixels 10
# car pixels 10
# car pixels 13
# car pixels 16
# car pixels 10
# car pixels 15
# car pixels 15
# car pixels 20
# car pixels 41
# car pixels 51
# car pixels 71
# car pixels 87
# car pixels 5631
# car pixels 861
# Total Reward for episode 0 is -180222

# %%
import os     
# Import Base Callback for saving models
from stable_baselines3.common.callbacks import BaseCallback
# Check Environment    
from stable_baselines3.common import env_checker

# %%
# env_checker.check_env(env)

# %%
from stable_baselines3.common.callbacks import BaseCallback
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1): 
        super(TrainAndLoggingCallback, self).__init__(verbose) 
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)  

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:  
            model_path = os.path.join(self.save_path, 'best_model_26march{}'.format(self.n_calls))
            self.model.save(model_path)

        return True
    
CHECKPOINT_DIR = './train/'
LOG_DIR = './logs/'

callback = TrainAndLoggingCallback(check_freq=1000, save_path=CHECKPOINT_DIR)

# %%
from stable_baselines3 import PPO 
from stable_baselines3.common.monitor import Monitor  
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
  
env = WebGame()
# First, wrap the environment in DummyVecEnv to make it compatible with VecFrameStack
env = DummyVecEnv([lambda: env])

# Now apply VecFrameStack to stack 4 frames
env = VecFrameStack(env, 4)

# %%
# model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1)  # Reduced by 10xlearning_starts=1000)
# Out:
# Using cpu device

# %%
model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1,clip_range=0.3,ent_coef=0.05,vf_coef=0.3,gae_lambda=0.98)     #23rd night changes
# Out:
# Using cpu device

# %%
model.load('train/best_model_26march30000')  # till here first rn everything

# %%
model.learn(total_timesteps=30000, callback=callback)
# Out:
# Logging to ./logs/PPO_2
# -----------------------------
# | time/              |      |
# |    fps             | 0    |
# |    iterations      | 1    |
# |    time_elapsed    | 2106 |
# |    total_timesteps | 2048 |
# -----------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 0         |
# |    iterations           | 2         |
# |    time_elapsed         | 4454      |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 19.454937 |
# |    clip_fraction        | 0.937     |
# |    clip_range           | 0.3       |
# |    entropy_loss         | -0.28     |
# |    explained_variance   | -5.76e-05 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 7.12e+03  |
# |    n_updates            | 10        |
# |    policy_gradient_loss | 0.495     |
# |    value_loss           | 3.24e+04  |
# ---------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 0             |
# |    iterations           | 3             |
# |    time_elapsed         | 6793          |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 1.1641532e-10 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -3.05e-07     |
# |    explained_variance   | 0.0272        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.11e+04      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -1.85e-06     |
# |    value_loss           | 1.32e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 0             |
# |    iterations           | 4             |
# |    time_elapsed         | 9148          |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00015787236 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -0.000128     |
# |    explained_variance   | 0.0306        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.33e+04      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | 7.07e-05      |
# |    value_loss           | 1.23e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 0             |
# |    iterations           | 5             |
# |    time_elapsed         | 11538         |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 3.3204327e-05 |
# |    clip_fraction        | 0.00151       |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -0.00325      |
# |    explained_variance   | 0.0886        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.43e+04      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | 0.000859      |
# |    value_loss           | 1.82e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 0             |
# |    iterations           | 6             |
# |    time_elapsed         | 13929         |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.00030073713 |
# |    clip_fraction        | 0.00186       |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -0.0042       |
# |    explained_variance   | 0.137         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.47e+04      |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -3.95e-06     |
# |    value_loss           | 1.3e+05       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 0             |
# |    iterations           | 7             |
# |    time_elapsed         | 16318         |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 0.00028466264 |
# |    clip_fraction        | 0.00142       |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -0.00353      |
# |    explained_variance   | 0.108         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.6e+04       |
# |    n_updates            | 60            |
# |    policy_gradient_loss | 0.000167      |
# |    value_loss           | 2.32e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 0            |
# |    iterations           | 8            |
# |    time_elapsed         | 18713        |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0006138043 |
# |    clip_fraction        | 0.00137      |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -0.00695     |
# |    explained_variance   | 0.141        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.1e+04      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | 3.02e-05     |
# |    value_loss           | 1.93e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 0             |
# |    iterations           | 9             |
# |    time_elapsed         | 21139         |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.00070058845 |
# |    clip_fraction        | 0.00195       |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -0.00457      |
# |    explained_variance   | 0.158         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.84e+04      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -8.05e-05     |
# |    value_loss           | 2.19e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 0             |
# |    iterations           | 10            |
# |    time_elapsed         | 23570         |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 0.00017121865 |
# |    clip_fraction        | 0.000879      |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -0.00281      |
# |    explained_variance   | 0.202         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.25e+05      |
# |    n_updates            | 90            |
# |    policy_gradient_loss | 6.65e-06      |
# |    value_loss           | 2.82e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 0             |
# |    iterations           | 11            |
# |    time_elapsed         | 26002         |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 0.00037161383 |
# |    clip_fraction        | 0.00195       |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -0.00728      |
# |    explained_variance   | 0.171         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.43e+04      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | 0.000188      |
# |    value_loss           | 3.15e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 0            |
# |    iterations           | 12           |
# |    time_elapsed         | 28453        |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0007900569 |
# |    clip_fraction        | 0.00303      |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -0.0102      |
# |    explained_variance   | 0.194        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.76e+04     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000408    |
# |    value_loss           | 2.62e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 0             |
# |    iterations           | 13            |
# |    time_elapsed         | 30910         |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00028111626 |
# |    clip_fraction        | 0.0019        |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -0.0103       |
# |    explained_variance   | 0.138         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.31e+04      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -2.71e-05     |
# |    value_loss           | 2.99e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 0            |
# |    iterations           | 14           |
# |    time_elapsed         | 33388        |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0056564435 |
# |    clip_fraction        | 0.00288      |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -0.00329     |
# |    explained_variance   | 0.248        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.05e+05     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | 9.07e-05     |
# |    value_loss           | 4.16e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 0           |
# |    iterations           | 15          |
# |    time_elapsed         | 35859       |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.005325758 |
# |    clip_fraction        | 0.00557     |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -0.0101     |
# |    explained_variance   | 0.134       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.18e+04    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.000204   |
# |    value_loss           | 2.79e+05    |
# -----------------------------------------

# %%
model.load('train/best_model_24march30000')

# %%
print(gym.__version__)
# Out:
# 0.26.2

# %%
for episode in range(2): 
    obs = env.reset()
    done = False
    total_reward = 0

    while not done: 
        action, _ = model.predict(obs)
            
        # Ensure action is properly formatted
        if isinstance(action, np.ndarray):  
            action = action.squeeze().tolist()  # Convert array to scalar/list
        obs, reward, done,info = env.step([action])  # Keep action as a list for VecEnv
        time.sleep(0.01)
        total_reward += reward
    
    print(f'Total Reward for episode {episode} is {total_reward}')
    time.sleep(2)
# Out:
# Total Reward for episode 0 is [-553.]
# Total Reward for episode 1 is [-1070.]
